# %%
from google.colab import drive
drive.mount('/content/drive')
#https://lambdalabs.com/blog/nvidia-a100-vs-v100-benchmarks.
#A100 is faster. But careful, it consumes too much compute units.
# Out:
# Mounted at /content/drive

# %%
# !pip install deeptrack mongoengine ruptures andi-datasets trackpy
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.10.0 which is incompatible.
# ...

# %%
# !nvidia-smi
# Out:
# Wed Apr 10 03:43:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              22W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !unzip /content/drive/MyDrive/wadtcn-2nd_andi_challenge.zip
# !cp -r ./wadtcn-2nd_andi_challenge/* .
# !rm -r wadtcn-2nd_andi_challenge
# !mkdir networks

# %%
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# %%
from PredictiveModel.UNetSingleParticleTracker import UNetSingleParticleTracker

for circle_size in [2,3,5,9]:
  network = UNetSingleParticleTracker(128,128,circle_size)
  network.hyperparameters['epochs'] = 10
  network.fit()
  network.save_as_file()

  import json
  with open(f"/content/drive/MyDrive/unet_single_particle_tracker_128x128_px_{circle_size}_radius.json", "w") as outfile:
      json.dump(network.history_training_info, outfile)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 16  160         ['input_2[0][0]']
#                                 )
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 128, 128, 16  0           ['conv2d_11[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 16  64         ['leaky_re_lu_10[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 16)  0           ['batch_normalization_10[0][0]']
#
# ...

# %%
# !cp /content/networks/*.h5 /content/drive/MyDrive

# %%
from google.colab import runtime
runtime.unassign()
